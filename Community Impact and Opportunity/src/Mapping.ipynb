# %%
# Helpful resource: http://andrewgaidus.com/leaflet_webmaps_python/
import pandas as pd
import geopandas as gpd
import folium
import pysal as ps
import os

project_dir = os.path.join(os.getcwd(), os.pardir)

# %%
df = pd.read_pickle(os.path.join(project_dir, 'data', 'joint_data_by_census.p'))
df.head()
# Out:
#    index tract_id_proper  ci_score  op_score        so       srb       shs  \
# 0      0               1      3.80  3.398696  0.167878  0.390522  0.353304
# 1      3              10      4.25  3.318182  0.140718  0.396273  0.480827
# 2      4           10.01      1.00  5.250000  0.133150  0.352400  0.435550
# 3      5           10.02      1.50  5.000000  0.137933  0.394933  0.309267
# 4      6             100      3.00  3.250000  0.117500  0.398500  0.573250
#
#         chc  County FIPS Code        tract tract_id
# 0  0.005217               107  42107000100   000100
# 1  0.004545                49  42049001000   001000
# 2  0.005000               101  42101001001   001001
# 3  0.003333               101  42101001002   001002
# 4  0.005000               101  42101010000   010000

# %%
pa_shape = gpd.read_file(os.path.join(project_dir, 'data', 'cb_2016_42_tract_500k.geojson'))

# %%
pa_shape.head()
# Out:
#   STATEFP COUNTYFP TRACTCE              AFFGEOID        GEOID NAME LSAD  \
# 0      42      101  010200  1400000US42101010200  42101010200  102   CT
# 1      42      101  011900  1400000US42101011900  42101011900  119   CT
# 2      42      101  013900  1400000US42101013900  42101013900  139   CT
# 3      42      101  015700  1400000US42101015700  42101015700  157   CT
# 4      42      101  016300  1400000US42101016300  42101016300  163   CT
#
#     ALAND  AWATER                                           geometry
# 0  360618       0  POLYGON ((-75.235356 39.968509, -75.235697 39....
# 1  690903       0  POLYGON ((-75.233672 39.991882, -75.225662 39....
# 2  562937       0  POLYGON ((-75.177852 39.974247, -75.173785 39....
# 3  485072       0  POLYGON ((-75.138768 39.979323, -75.138137 39....
# 4  572226       0  POLYGON ((-75.139021 39.988764, -75.138352 39....

# %%
gdf = pa_shape.merge(df, left_on='TRACTCE', right_on='tract_id')
gdf.head()
# Out:
#   STATEFP COUNTYFP TRACTCE              AFFGEOID        GEOID NAME LSAD  \
# 0      42      101  010200  1400000US42101010200  42101010200  102   CT
# 1      42      027  010200  1400000US42027010200  42027010200  102   CT
# 2      42      095  010200  1400000US42095010200  42095010200  102   CT
# 3      42      081  010200  1400000US42081010200  42081010200  102   CT
# 4      42      021  010200  1400000US42021010200  42021010200  102   CT
#
#        ALAND   AWATER                                           geometry  \
# 0     360618        0  POLYGON ((-75.235356 39.968509, -75.235697 39....
# 1  451226567  2062239  POLYGON ((-78.112239 41.114217, -78.104866 41....
# 2    7307701    81905  POLYGON ((-75.396869 40.644551, -75.387272 40....
# 3  626695968  5634589  POLYGON ((-77.599278 41.542271, -77.454835 41....
# 4    2129479    55811  POLYGON ((-78.89387600000001 40.338569, -78.89...
#
#      ...     tract_id_proper ci_score  op_score        so       srb       shs  \
# 0    ...                 102     2.25  3.504444  0.172978  0.317072  0.235817
# 1    ...                 102     2.25  3.504444  0.172978  0.317072  0.235817
# 2    ...                 102     2.25  3.504444  0.172978  0.317072  0.235817
# 3    ...                 102     2.25  3.504444  0.172978  0.317072  0.235817
# 4    ...                 102     2.25  3.504444  0.172978  0.317072  0.235817
#
#         chc  County FIPS Code        tract  tract_id
# 0  0.001667                81  42081010200    010200
# 1  0.001667                81  42081010200    010200
# 2  0.001667                81  42081010200    010200
# 3  0.001667                81  42081010200    010200
# 4  0.001667                81  42081010200    010200
#
# [5 rows x 21 columns]

# %%
pa_map = folium.Map([41.203323, -77.194527], zoom_start = 7)
pa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gdf_wgs84 = gdf.to_crs(epsg=4326)

# %%
def add_choropleth(mapobj, gdf, id_field, value_field, fill_color = 'YlOrRd', fill_opacity = 0.6, 
                    line_opacity = 0.2, num_classes = 5, classifier = 'Fisher_Jenks'):
    #Allow for 3 Pysal map classifiers to display data
    #Generate list of breakpoints using specified classification scheme. List of breakpoint will be input to choropleth function
    if classifier == 'Fisher_Jenks':
        threshold_scale=ps.esda.mapclassify.Fisher_Jenks(gdf[value_field], k = num_classes).bins.tolist()
    if classifier == 'Equal_Interval':
        threshold_scale=ps.esda.mapclassify.Equal_Interval(gdf[value_field], k = num_classes).bins.tolist()
    if classifier == 'Quantiles':
        threshold_scale=ps.esda.mapclassify.Quantiles(gdf[value_field], k = num_classes).bins.tolist()
    
    #Convert the GeoDataFrame to WGS84 coordinate reference system
#     gdf_wgs84 = gdf.to_crs(epsg=4326)
    
    #Call Folium choropleth function, specifying the geometry as a the WGS84 dataframe converted to GeoJSON, the data as 
    #the GeoDataFrame, the columns as the user-specified id field and and value field.
    #key_on field refers to the id field within the GeoJSON string
    layer = folium.FeatureGroup(name=value_field)
    layer.add_child(mapobj.choropleth(geo_str = gdf_wgs84.to_json(), data = gdf,
                columns = [id_field, value_field], key_on = 'feature.properties.{}'.format(id_field),
                fill_color = fill_color, fill_opacity = fill_opacity, line_opacity = line_opacity,  
                threshold_scale = threshold_scale), value_field)
    mapobj.add_children(layer)
    return mapobj

# %%
#Update basemap with choropleth
pa_map=add_choropleth(pa_map, gdf_wgs84, 'TRACTCE','ci_score')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-d5c83edc03d3> in <module>()
#       1 #Update basemap with choropleth
# ----> 2 pa_map=add_choropleth(pa_map, gdf_wgs84, 'TRACTCE','ci_score')
#
# <ipython-input-71-32d3814135b1> in add_choropleth(mapobj, gdf, id_field, value_field, fill_color, fill_opacity, line_opacity, num_classes, classifier)
#      20                 columns = [id_field, value_field], key_on = 'feature.properties.{}'.format(id_field),
#      21                 fill_color = fill_color, fill_opacity = fill_opacity, line_opacity = line_opacity,
# ---> 22                 threshold_scale = threshold_scale), value_field)
#      23     mapobj.add_children(layer)
#      24     return mapobj
#
# ~\Anaconda3\envs\ds\lib\site-packages\branca\element.py in add_child(self, child, name, index)
#     102             items.insert(int(index), (name, child))
#     103             self._children = items
# --> 104         child._parent = self
#     105         return self
#     106
#
# AttributeError: 'NoneType' object has no attribute '_parent'

# %%
def add_point_clusters(mapobj, gdf, popup_field_list):
    #Create empty lists to contain the point coordinates and the point pop-up information
    coords, popups = [], [] 
    #Loop through each record in the GeoDataFrame
    for i, row in gdf.iterrows():
        #Append lat and long coordinates to "coords" list
        coords.append([row.geometry.y, row.geometry.x])
        #Create a string of HTML code used in the IFrame popup
        #Join together the fields in "popup_field_list" with a linebreak between them
        label = '<br>'.join([row[field] for field in popup_field_list])
        #Append an IFrame that uses the HTML string to the "popups" list 
        popups.append(IFrame(label, width = 300, height = 100))
        
    #Create a Folium feature group for this layer, since we will be displaying multiple layers
    pt_lyr = folium.FeatureGroup(name = 'pt_lyr')
    
    #Add the clustered points of crime locations and popups to this layer
    pt_lyr.add_children(MarkerCluster(locations = coords, popups = popups))
    
    #Add this point layer to the map object
    mapobj.add_children(pt_lyr)
    return mapobj

#Update choropleth with point clusters
pa_map = add_point_clusters(pa_map, gdf, ['ci_score'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-d3da63fd6a37> in <module>()
#      23
#      24 #Update choropleth with point clusters
# ---> 25 pa_map = add_point_clusters(pa_map, gdf, ['ci_score'])
#
# <ipython-input-47-d3da63fd6a37> in add_point_clusters(mapobj, gdf, popup_field_list)
#       5     for i, row in gdf.iterrows():
#       6         #Append lat and long coordinates to "coords" list
# ----> 7         coords.append([row.geometry.y, row.geometry.x])
#       8         #Create a string of HTML code used in the IFrame popup
#       9         #Join together the fields in "popup_field_list" with a linebreak between them
#
# AttributeError: 'Polygon' object has no attribute 'y'

# %%
folium.LayerControl().add_to(pa_map) #Add layer control to toggle on/off

# %%
pa_map.save(os.path.join(project_dir, 'data', 'output.html'))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-58-faa9cc0a3a4b> in <module>()
# ----> 1 pa_map.save(os.path.join(project_dir, 'data', 'output.html'))
#
# ~\Anaconda3\envs\ds\lib\site-packages\branca\element.py in save(self, outfile, close_file, **kwargs)
#     155
#     156         root = self.get_root()
# --> 157         html = root.render(**kwargs)
#     158         fid.write(html.encode('utf8'))
#     159         if close_file:
#
# ~\Anaconda3\envs\ds\lib\site-packages\branca\element.py in render(self, **kwargs)
#     596         """Renders the HTML representation of the element."""
#     597         figure = self.get_root()
# --> 598         assert isinstance(figure, Figure), ("You cannot render this Element "
#     599                                             "if it's not in a Figure.")
#     600
#
# AssertionError: You cannot render this Element if it's not in a Figure.

# %%
gdf.to_file(os.path.join(project_dir, 'data', 'output.geojson'))
gdf.to_file(os.path.join(project_dir, 'data', 'output.cs

# %%
gdf.to_file(os.path.join(project_dir, 'data', 'output.dgn'), driver='DGN')
# Out:
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.start()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_AppDefinedError: No seed file provided, and unable to find seed_2d.dgn.
#
# During handling of the above exception, another exception occurred:
#
# DriverIOError                             Traceback (most recent call last)
# <ipython-input-84-2891d84e63b4> in <module>()
# ----> 1 gdf.to_file(os.path.join(project_dir, 'data', 'output.dgn'), driver='DGN')
#
# ~\Anaconda3\envs\ds\lib\site-packages\geopandas\geodataframe.py in to_file(self, filename, driver, schema, **kwargs)
#     363         """
#     364         from geopandas.io.file import to_file
# --> 365         to_file(self, filename, driver, schema, **kwargs)
#     366
#     367     def to_crs(self, crs=None, epsg=None, inplace=False):
#
# ~\Anaconda3\envs\ds\lib\site-packages\geopandas\io\file.py in to_file(df, filename, driver, schema, **kwargs)
#      62     with fiona.drivers():
#      63         with fiona.open(filename, 'w', driver=driver, crs=df.crs,
# ---> 64                         schema=schema, **kwargs) as colxn:
#      65             for feature in df.iterfeatures():
#      66                 colxn.write(feature)
#
# ~\Anaconda3\envs\ds\lib\site-packages\fiona\__init__.py in open(path, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt)
#     173         c = Collection(path, mode, crs=crs, driver=driver, schema=this_schema,
#     174                        encoding=encoding, layer=layer, vsi=vsi, archive=archive,
# --> 175                        enabled_drivers=enabled_drivers, crs_wkt=crs_wkt)
#     176     else:
#     177         raise ValueError(
#
# ~\Anaconda3\envs\ds\lib\site-packages\fiona\collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, **kwargs)
#     154             elif self.mode in ('a', 'w'):
#     155                 self.session = WritingSession()
# --> 156                 self.session.start(self, **kwargs)
#     157         except IOError:
#     158             self.session = None
#
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.start()
#
# DriverIOError: No seed file provided, and unable to find seed_2d.dgn.
